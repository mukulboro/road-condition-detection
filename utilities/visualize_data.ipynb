# %% [markdown]
# ## Importing required libraries

# %%
import pandas as pd

# %%
file_path = "../model/road_condition_data/" # File path to directory

# %% [markdown]
# ## Create pandas dataframe

# %%
df = pd.read_csv(file_path+"annotations.csv")

df.head(10)
# Out:
#    Unnamed: 0 image_name  has_potholes  rating  is_pitched  has_cracks
# 0           0   1600.jpg             1       2           1           1
# 1           1   1601.jpg             1       2           1           1
# 2           2   1602.jpg             1       2           1           1
# 3           3   1610.jpg             0       3           1           0
# 4           4   1611.jpg             0       3           1           0
# 5           5   1612.jpg             0       3           1           0
# 6           6   1620.jpg             1       2           1           1
# 7           7   1621.jpg             1       2           1           1
# 8           8   1622.jpg             1       2           1           1
# 9           9   1630.jpg             1       2           1           1

# %%
rev_df = df.iloc[::-1] # Reversing the dataframe
rev_df.head(10)
# Out:
#        Unnamed: 0            image_name  has_potholes  rating  is_pitched  \
# 21775       21775  UngradedRoad_992.jpg             1       2           1
# 21774       21774  UngradedRoad_991.jpg             1       2           1
# 21773       21773  UngradedRoad_990.jpg             1       2           1
# 21772       21772  UngradedRoad_982.jpg             1       1           1
# 21771       21771  UngradedRoad_981.jpg             1       1           1
# 21770       21770  UngradedRoad_980.jpg             1       1           1
# 21769       21769  UngradedRoad_972.jpg             1       1           1
# 21768       21768  UngradedRoad_971.jpg             1       1           1
# 21767       21767  UngradedRoad_970.jpg             1       1           1
# 21766       21766  UngradedRoad_962.jpg             1       1           1
#
#        has_cracks
# 21775           1
# 21774           1
# 21773           1
# 21772           1
# 21771           1
# 21770           1
# 21769           1
# 21768           1
# 21767           1
# 21766           1

# %% [markdown]
# ## Looking at data

# %%
total_data = len(df)
no_of_pothole_images = len(df[df.has_potholes==1])
no_of_pitched_images = len(df[df.is_pitched==1])
no_of_cracks_images = len(df[df.has_cracks==1])

print(f"Total number of datapoints: {total_data}")
print(f"Has potholes: {no_of_pothole_images}/{total_data} [{(no_of_pothole_images/total_data)*100:.3f}%]")
print(f"Is pitched: {no_of_pitched_images}/{total_data} [{(no_of_pitched_images/total_data)*100:.3f}%]")
print(f"Has Cracks: {no_of_cracks_images}/{total_data} [{(no_of_cracks_images/total_data)*100:.3f}%]")
# Out:
# Total number of datapoints: 21776
# Has potholes: 4298/21776 [19.737%]
# Is pitched: 16733/21776 [76.841%]
# Has Cracks: 13266/21776 [60.920%]

# %%
df.to_csv("annotations.csv") # Save pandas dataframe to file
